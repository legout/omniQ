# %%
import nest_asyncio
nest_asyncio.apply()
from omniq.workers import (
    ThreadPoolWorker,
    AsyncWorker,
    AsyncGeventWorker,
    AsyncProcessWorker,
    GeventPoolWorker,
    ProcessPoolWorker,
)

import datetime as dt
from omniq.queue import (
    AsyncFileQueue,
    AsyncSQLiteQueue,
    AsyncNATSQueue,
    AsyncRedisQueue,
    AsyncPostgresQueue,
)
from omniq.results import (
    AsyncFileResultStorage,
    AsyncSQLiteResultStorage,
    AsyncNATSResultStorage,
    AsyncRedisResultStorage,
    AsyncPostgresResultStorage,
)
from omniq.events import (
    AsyncPostgresEventStorage,
    AsyncFileEventStorage,
    AsyncSQLiteEventStorage,
)

# %%
# Create components individually
queue = AsyncSQLiteQueue(
    db_path="some/path/sqlite.db"
)

result_store = AsyncSQLiteResultStorage(
    db_path="some/path/sqlite.db"
)

event_store = AsyncSQLiteEventStorage(db_path="some/path/sqlite.db")

print("Created individual components:")
print(f"- Task Queue: {type(queue).__name__}")
print(f"- Result Store: {type(result_store).__name__}")
# Out:
# Created individual components:
# - Task Queue: AsyncSQLiteQueue
# - Result Store: AsyncSQLiteResultStorage

# %%
# Create worker with reference to queue and result store
worker = AsyncWorker(
    queue=queue,
    result_storage=result_store,
    event_storage=event_store,
)

# %%
# Define a task
def simple_task(name):
    print(f"Hello {name}")
    return name

print("Defined simple_task function")
# Out:
# Defined simple_task function

# %%
# Enqueue a task
from omniq import Task

task_id = await queue.enqueue_async(
    func=simple_task,
    kwargs=dict(name="Tom"),
    queue_name="low"
)
print(f"Enqueued task with ID: {task_id}")
# Out:
# Enqueued task with ID: None

# %%
await worker.start()

# %%
await worker.stop()

# %%
await queue.enqueue_async?
# Out:
# Signature:
# queue.enqueue_async(
#     task: Optional[omniq.models.task.Task] = None,
#     func: Optional[Callable] = None,
#     func_name: Optional[str] = None,
#     args: Optional[Tuple] = None,
#     kwargs: Optional[Dict] = None,
#     ttl: Optional[datetime.timedelta] = None,
#     queue_name: str = 'default',
# ) -> None
# Docstring: Enqueue a task asynchronously.
# File:      ~/coding/libs/omniQ/restart/src/omniq/queue/sqlite.py
# Type:      method

# %%
import httpx
def simple_task():
    return httpx.get("https://petstore.swagger.io/v2/pet/findByStatus?status=available").json()

# %%
with open("simple_task.pkl", "wb") as f:
    pickle.dump(simple_task, f)

# %%
test()
# Out:
# [{'id': 9223372036854740166,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740167,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740189,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740191,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740193,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740201,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740216,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740217,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740219,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740225,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740239,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740240,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740254,
#   'category': {'id': 0, 'name': 'cats'},
#   'name': 'Tom',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740261,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740262,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740263,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 322,
#   'name': 'Fujikq',
#   'photoUrls': ['Fuji-pic.com'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740272,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740275,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 132,
#   'category': {'id': 0, 'name': 'dickey'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 100, 'name': 'bowman'}],
#   'status': 'available'},
#  {'id': 9223372036854740285,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740286,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740296,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740309,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740310,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740312,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740323,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 574891,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740350,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740354,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740357,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740358,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740361,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'test',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740362,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'test',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740376,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9222968140491042131,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740379,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 2235,
#   'category': {'id': 0, 'name': 'semih'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1234567,
#   'category': {'id': 1, 'name': 'cat'},
#   'name': 'Dymochok',
#   'photoUrls': ['https://example.com/photos/bella1.jpg'],
#   'tags': [{'id': 1, 'name': 'angry'}],
#   'status': 'available'},
#  {'id': 9223372036854740408,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740409,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740410,
#   'category': {'id': 0, 'name': 'Roger'},
#   'name': 'Dinosaur',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740413,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740416,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740422,
#   'name': 'pet11',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740423,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740426,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'cat',
#   'photoUrls': ['https://klike.net/uploads/posts/2023-01/1675061232_3-62.jpg'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740439,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1754816113448,
#   'name': 'QaPet',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740445,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740446,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740456,
#   'name': 'pet11',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740483,
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 777,
#   'category': {'id': 1, 'name': 'cats'},
#   'name': 'Barsik',
#   'photoUrls': ['https://example.com/barsik.jpg'],
#   'tags': [{'id': 1, 'name': 'fluffy'}],
#   'status': 'available'},
#  {'id': 9223372036854740487,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740489,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740491,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740498,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740501,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9222968140497180179,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'test',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740510,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740511,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740512,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740516,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740518,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740524,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 230,
#   'category': {'id': 240, 'name': 'maxi'},
#   'name': 'doggie',
#   'photoUrls': ['https://thumbor.forbes.com/thumbor/fit-in/1290x/https://www.forbes.com/advisor/wp-content/uploads/2023/07/top-20-small-dog-breeds.jpeg.jpg'],
#   'tags': [{'id': 120, 'name': 'amith'}],
#   'status': 'available'},
#  {'id': 9223372036854740534,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 131,
#   'category': {'id': 0, 'name': 'dickey'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 100, 'name': 'bowman'}],
#   'status': 'available'},
#  {'id': 9223372036854740539,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740542,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740543,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740546,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'Puff',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1754821962562,
#   'name': 'LuigisPet',
#   'photoUrls': ['https://example.com'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740554,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740565,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1754822406121,
#   'name': 'LuigisPet',
#   'photoUrls': ['https://example.com'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740576,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740578,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740586,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 14342,
#   'category': {'id': 3, 'name': 'dogs'},
#   'name': 'diggie',
#   'photoUrls': ['https://example.com/barsik.jpg'],
#   'tags': [{'id': 2, 'name': 'puppy'}],
#   'status': 'available'},
#  {'id': 9223372036854740589,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1364,
#   'name': 'QaPet',
#   'photoUrls': ['www.example.com'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 1754822788469,
#   'name': 'LuigisPet',
#   'photoUrls': ['https://example.com'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 7022,
#   'name': 'QaPet',
#   'photoUrls': ['www.example.com'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 112233,
#   'category': {'id': 30, 'name': 'Eq-dog'},
#   'name': 'Postman',
#   'photoUrls': ['URLLink'],
#   'tags': [{'id': 10, 'name': 'Doberman'}],
#   'status': 'available'},
#  {'id': 11,
#   'category': {'id': 14, 'name': 'string'},
#   'name': 'jack',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740609,
#   'category': {'id': 0, 'name': 'Puppy'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740613,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740636,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740637,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740646,
#   'category': {'id': 1, 'name': 'test'},
#   'name': 'doggie',
#   'photoUrls': [],
#   'tags': [{'id': 1, 'name': 'test'}],
#   'status': 'available'},
#  {'id': 9223372036854740648,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 111,
#   'category': {'id': 10, 'name': 'Dog'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740659,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740672,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740685,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740687,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 31072026,
#   'category': {'id': 0, 'name': 'Foxy'},
#   'name': 'cat',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740693,
#   'category': {'id': 0, 'name': 'Roger'},
#   'name': 'Dinosaur',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 4567,
#   'category': {'id': 1, 'name': 'mammal'},
#   'name': 'cotton',
#   'photoUrls': ['string'],
#   'tags': [{'id': 2, 'name': 'lovely'}],
#   'status': 'available'},
#  {'id': 9223372036854740697,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740699,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740701,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740702,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740703,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740709,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740724,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740730,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740745,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740749,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740750,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740751,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740759,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740765,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1754824710546,
#   'category': {'id': 10, 'name': 'Cats'},
#   'name': 'Funny',
#   'photoUrls': ['string'],
#   'tags': [{'id': 1, 'name': 'blue and brown'},
#    {'id': 2, 'name': 'green eyes'},
#    {'id': 3, 'name': 'cute'}],
#   'status': 'available'},
#  {'id': 1754824712990,
#   'category': {'id': 10, 'name': 'Cats'},
#   'name': 'Funny',
#   'photoUrls': ['string'],
#   'tags': [{'id': 1, 'name': 'blue and brown'},
#    {'id': 2, 'name': 'green eyes'},
#    {'id': 3, 'name': 'cute'}],
#   'status': 'available'},
#  {'id': 1754824717465,
#   'category': {'id': 10, 'name': 'Cats'},
#   'name': 'Funny',
#   'photoUrls': ['string'],
#   'tags': [{'id': 1, 'name': 'blue and brown'},
#    {'id': 2, 'name': 'green eyes'},
#    {'id': 3, 'name': 'cute'}],
#   'status': 'available'},
#  {'id': 9223372036854740769,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740773,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740774,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740775,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740802,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740803,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740806,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740807,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740808,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740810,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 5432,
#   'name': 'doggie',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740825,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740826,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740827,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740828,
#   'category': {'id': 0, 'name': 'SHera'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740829,
#   'category': {'id': 0, 'name': 'sdfgjhk'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 406,
#   'category': {'id': 406, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 406, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740830,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740831,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740837,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740842,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740844,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740858,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740865,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'erster',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740875,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740879,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740893,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740895,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740896,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'kitty',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740899,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740907,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740912,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1711,
#   'category': {'id': 1711, 'name': 'Собаки'},
#   'name': 'Арчи',
#   'photoUrls': ['https://api.zapovednik96.ru/upload/iblock/f0e/shutterstock_2433293809.jpg'],
#   'tags': [{'id': 1711, 'name': 'собака'}],
#   'status': 'available'},
#  {'id': 9223372036854740924,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740925,
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740927,
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740929,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740930,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'test',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740933,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740934,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740941,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'Jimmy',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740942,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740961,
#   'category': {'id': 0, 'name': 'Puppy'},
#   'name': 'Jimmy',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740962,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740964,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740965,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740966,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854740989,
#   'category': {'id': 0, 'name': 'tayfTayf'},
#   'name': 'tayfTayf',
#   'photoUrls': [None],
#   'tags': [{'id': 0, 'name': 'tayfTayf'}],
#   'status': 'available'},
#  {'id': 9223372036854740995,
#   'category': {'id': 0, 'name': 'dog'},
#   'name': 'Leo',
#   'photoUrls': ['https://www.akc.org/wp-content/uploads/2017/11/German-Shepherd-on-White-00.jpg'],
#   'tags': [{'id': 0, 'name': 'GermanShepherd'}],
#   'status': 'available'},
#  {'id': 12345,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'blabla',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740998,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854740999,
#   'category': {'id': 2, 'name': 'cat'},
#   'name': 'purplefieldstester10738130181',
#   'photoUrls': ['http://purplefieldstestimage1',
#    'http://purplefieldstestimage2'],
#   'tags': [{'id': 1, 'name': 'naughty'}, {'id': 2, 'name': 'nice'}],
#   'status': 'available'},
#  {'id': 9223372036854741000,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741002,
#   'category': {'id': 1, 'name': 'cat1'},
#   'name': 'purplefieldstester1',
#   'photoUrls': ['https://purplefieldstestimage1',
#    'https://purplefieldstestimage2'],
#   'tags': [{'id': 1, 'name': 'naughty'}, {'id': 2, 'name': 'nice'}],
#   'status': 'available'},
#  {'id': 9223372036854741008,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 2345678,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Duman',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'My lovely cat'}],
#   'status': 'available'},
#  {'id': 7895443,
#   'category': {'id': 0, 'name': 'Fish'},
#   'name': 'Fishie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741017,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741018,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 4560,
#   'category': {'id': 0, 'name': 'Cat'},
#   'name': 'Ginger',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'Pets'}],
#   'status': 'available'},
#  {'id': 9223372036854741021,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 2,
#   'category': {'id': 0, 'name': 'dog'},
#   'name': 'Tom',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 123,
#   'category': {'id': 2, 'name': 'félins'},
#   'name': 'putty',
#   'photoUrls': ['string'],
#   'tags': [{'id': 1, 'name': 'domestique'}],
#   'status': 'available'},
#  {'id': 9223372036854741025,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'doggietest',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741026,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'cat',
#   'photoUrls': ['https://klike.net/uploads/posts/2023-01/1675061232_3-62.jpg'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741032,
#   'name': 'kotte',
#   'photoUrls': [],
#   'tags': [],
#   'status': 'available'},
#  {'id': 9223372036854741055,
#   'category': {'id': 0, 'name': 'sg'},
#   'name': 'dog',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 1245,
#   'category': {'id': 1245, 'name': 'xyz'},
#   'name': 'xyz',
#   'photoUrls': ['test'],
#   'tags': [],
#   'status': 'available'},
#  {'id': 1,
#   'category': {'id': 1, 'name': 'string'},
#   'name': 'doggie',
#   'photoUrls': ['string'],
#   'tags': [{'id': 1, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741077,
#   'category': {'id': 0, 'name': 'string'},
#   'name': 'fish',
#   'photoUrls': ['string'],
#   'tags': [{'id': 0, 'name': 'string'}],
#   'status': 'available'},
#  {'id': 9223372036854741080,
#   'category': {'id': 100, 'name': 'Dinosaur'},
#   'name': 'Tyrannosaurus',
#   'photoUrls': ['http://en.wikipedia.org/wiki/Tyrannosaurus#/media/File:Tyrannosaurus_rex_mmartyniuk.png'],
#   'tags': [{'id': 100, 'name': 'reptile'}, {'id': 101, 'name': 'dinosaur'}],
#   'status': 'available'}]
